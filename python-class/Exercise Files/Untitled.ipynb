# %%
def to_celsius(x):
   return (x-32) * 5/9
print(to_celsius(75))
# Out:
# 23.88888888888889

# %%
number = 100
if number > 0:
    print('Number is positive.')
elif number == 0:
    print('Number is zero.')
else:
    print('Number is negative.')
# Out:
# Number is positive.

# %%
Apple_&_oranges = 10
# Out:
#   Cell In[14], line 1
#     Apple_&_oranges = 10
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
name: str = "Betty"

# %% [raw]
# age: int = 35

# %%
type("Min")
# Out:
# str

# %%
type(10)
# Out:
# int

# %%
original_list = [22, "FF", 33, 123, 22, 123, 45, 0x0f, 66, 0x0f, 77]

sorted_by_frequency = sorted(original_list, key=lambda x: original_list.count(x), reverse=True)

print(sorted_by_frequency)
# Out:
# [22, 123, 22, 123, 15, 15, 'FF', 33, 45, 66, 77]

# %%
original_list = [12, 2, 32, 19, 57, 22, 14]
sorted_list_ascending = sorted(original_list, reverse=False)

print(sorted_list_ascending)
# Out:
# [2, 12, 14, 19, 22, 32, 57]

# %%
def area_triangle(base, height):
    return base*height/2

# %%
area_a = area_triangle(5,4)
print(area_a)
area_b = area_triangle(7,3)
# Out:
# 10.0
